# %%
#Large negative: low processing power
#Large positive: collaborative coding
print("hello")
# Out:
# hello

# %%
import pandas as pd
from google.colab import drive
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive/', force_remount = True)
#Watch Out! This code will allow people do view your whole google drive. Watch out if you have sensitive data
# Out:
# Mounted at /content/gdrive/

# %%
df = pd.read_csv("/content/gdrive/MyDrive/Econ_441B/winequality-red.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
plt.figure(figsize = (12,8))
plt.hist(df["alcohol"])
plt.xlabel("Alcohol Content")
plt.ylabel("Frequency")
plt.title("Alcohol Content Distribution, Red Wine")
plt.grid()
plt.show()

# %%
#Data Observation: Alcohol Content follows a Poison Dist.
